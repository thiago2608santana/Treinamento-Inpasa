# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
df_corn = pd.read_csv('./Commodities Futures Collection/grains_and_cereals_futures/individual_data/Corn_data.csv')
df_rice = pd.read_csv('./Commodities Futures Collection/grains_and_cereals_futures/individual_data/Rough_Rice_data.csv')

# %%
df_corn.head()
# Out:
#          date    open    high     low   close  volume
# 0  2000-07-17  182.25  182.25  178.25  179.25   19385
# 1  2000-07-18  179.00  183.25  179.00  180.75   25205
# 2  2000-07-19  180.00  182.75  178.75  182.00   17126
# 3  2000-07-20  181.50  187.00  181.00  186.00   18742
# 4  2000-07-21  185.50  188.00  185.00  187.75   16814

# %%
df_rice.head()
# Out:
#          date        open        high         low       close  volume
# 0  2000-01-03  636.650024  640.950012  640.950012  636.650024       0
# 1  2000-01-04  636.650024  640.950012  640.950012  629.450012       0
# 2  2000-01-05  629.450012  640.950012  640.950012  626.500000       0
# 3  2000-01-06  626.500000  640.950012  640.950012  627.299988       0
# 4  2000-01-07  627.299988  640.950012  640.950012  624.349976       0

# %%
round(df_rice.loc[0, 'open'],6)
# Out:
# 636.650024

# %%
df_corn['date'] = df_corn['date'].apply(lambda x : datetime.datetime.strptime(x, '%Y-%m-%d'))
df_oat['date'] = df_oat['date'].apply(lambda x : datetime.datetime.strptime(x, '%Y-%m-%d'))

# %%
df_corn.set_index('date', inplace=True)
df_oat.set_index('date', inplace=True)

# %%
df_corn.head()
# Out:
#               open    high     low   close  volume
# date
# 2000-07-17  182.25  182.25  178.25  179.25   19385
# 2000-07-18  179.00  183.25  179.00  180.75   25205
# 2000-07-19  180.00  182.75  178.75  182.00   17126
# 2000-07-20  181.50  187.00  181.00  186.00   18742
# 2000-07-21  185.50  188.00  185.00  187.75   16814

# %%
df_corn
# Out:
#               open    high     low   close  volume
# date
# 2000-07-17  182.25  182.25  178.25  179.25   19385
# 2000-07-18  179.00  183.25  179.00  180.75   25205
# 2000-07-19  180.00  182.75  178.75  182.00   17126
# 2000-07-20  181.50  187.00  181.00  186.00   18742
# 2000-07-21  185.50  188.00  185.00  187.75   16814
# ...            ...     ...     ...     ...     ...
# 2024-05-22  458.50  463.25  458.00  461.25  175899
# 2024-05-23  461.25  467.25  458.50  464.00  166864
# 2024-05-24  464.50  466.75  460.75  464.75  169182
# 2024-05-28  467.00  471.00  460.00  462.50  166128
# 2024-05-29  455.25  456.50  454.25  455.50    9989
#
# [5970 rows x 5 columns]

# %%
df_oat.head()
# Out:
#                   open        high         low       close  volume
# date
# 2000-01-03  636.650024  640.950012  640.950012  636.650024       0
# 2000-01-04  636.650024  640.950012  640.950012  629.450012       0
# 2000-01-05  629.450012  640.950012  640.950012  626.500000       0
# 2000-01-06  626.500000  640.950012  640.950012  627.299988       0
# 2000-01-07  627.299988  640.950012  640.950012  624.349976       0

# %%
df_oat
# Out:
#                    open         high          low        close  volume
# date
# 2000-01-03   636.650024   640.950012   640.950012   636.650024       0
# 2000-01-04   636.650024   640.950012   640.950012   629.450012       0
# 2000-01-05   629.450012   640.950012   640.950012   626.500000       0
# 2000-01-06   626.500000   640.950012   640.950012   627.299988       0
# 2000-01-07   627.299988   640.950012   640.950012   624.349976       0
# ...                 ...          ...          ...          ...     ...
# 2024-05-22  1858.000000  1880.000000  1856.500000  1875.000000     344
# 2024-05-23  1881.500000  1900.500000  1838.000000  1848.500000     522
# 2024-05-24  1846.000000  1848.500000  1830.000000  1834.000000     587
# 2024-05-28  1846.000000  1859.500000  1805.000000  1809.000000     681
# 2024-05-29    17.820000    17.910000    17.780001    17.799999      32
#
# [6113 rows x 5 columns]

# %%
plt.plot(df_corn['high'])

# %%
plt.plot(df_oat['high'])
